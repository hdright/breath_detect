# %%
from torchstat import stat
from bdn.backbone import RegLSTM, BDCNN, BDCNNold, BDCNN_ND, BDInception3

# %%
modelBDCNN = BDCNN(input_sample=270, output_size=600)
stat(modelBDCNN, (3, 90, 600))
# Out:
# [MAdd]: Dropout is not supported!
# [Flops]: Dropout is not supported!
# [Memory]: Dropout is not supported!
# [MAdd]: Dropout is not supported!
# [Flops]: Dropout is not supported!
# [Memory]: Dropout is not supported!
# [MAdd]: Dropout is not supported!
# [Flops]: Dropout is not supported!
# [Memory]: Dropout is not supported!
# [MAdd]: Dropout is not supported!
# [Flops]: Dropout is not supported!
# [Memory]: Dropout is not supported!
#       module name  input shape output shape       params memory(MB)             MAdd            Flops   MemRead(B)  MemWrite(B) duration[%]    MemR+W(B)
# 0         conv1.0    3  90 600   64  22 114     121024.0       0.61    606,735,360.0    303,528,192.0    1132096.0     642048.0       7.62%    1774144.0
# 1         conv1.1   64  22 114   64  20 104     430144.0       0.51  1,789,132,800.0    894,699,520.0    2362624.0     532480.0       9.52%    2895104.0
# ...

# %%
modelBDincep = BDInception3(input_sample=960, output_size=600)
stat(modelBDincep, (3, 320, 600))
# Out:
#                          module name   input shape output shape      params memory(MB)              MAdd            Flops  MemRead(B)  MemWrite(B) duration[%]    MemR+W(B)
# 0                 Conv2d_1a_3x3.conv     3 320 600   32 141 141    153600.0       2.43   6,106,807,008.0  3,053,721,600.0   2918400.0    2544768.0      17.30%    5463168.0
# 1                   Conv2d_1a_3x3.bn    32 141 141   32 141 141        64.0       2.43       2,544,768.0      1,272,384.0   2545024.0    2544768.0       0.49%    5089792.0
# 2                 Conv2d_2a_3x3.conv    32 141 141   32 139 139      9216.0       2.36     355,506,400.0    178,062,336.0   2581632.0    2473088.0       1.13%    5054720.0
# 3                   Conv2d_2a_3x3.bn    32 139 139   32 139 139        64.0       2.36       2,473,088.0      1,236,544.0   2473344.0    2473088.0       0.39%    4946432.0
# ...
